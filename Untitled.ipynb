# %%
# %run client3.py
# Out:
# Quoted ABC at (bid:111.62, ask:110.27, price:111.62)
# Quoted DEF at (bid:112.29, ask:111.68, price:112.29)
# Ratio 1
# Quoted ABC at (bid:111.62, ask:110.27, price:111.62)
# Quoted DEF at (bid:112.29, ask:111.68, price:112.29)
# Ratio 1
# Quoted ABC at (bid:111.62, ask:110.27, price:111.62)
# Quoted DEF at (bid:112.29, ask:111.68, price:112.29)
# Ratio 1
# Quoted ABC at (bid:111.62, ask:110.27, price:111.62)
# Quoted DEF at (bid:112.29, ask:111.68, price:112.29)
# Ratio 1
# Quoted ABC at (bid:111.62, ask:110.27, price:111.62)
# Quoted DEF at (bid:112.29, ask:111.68, price:112.29)
# Ratio 1
# Quoted ABC at (bid:111.62, ask:110.27, price:111.62)
# Quoted DEF at (bid:112.29, ask:111.68, price:112.29)
# Ratio 1
# Quoted ABC at (bid:111.62, ask:110.27, price:111.62)
# Quoted DEF at (bid:112.29, ask:111.68, price:112.29)
# Ratio 1
# Quoted ABC at (bid:111.62, ask:110.27, price:111.62)
# Quoted DEF at (bid:112.29, ask:111.68, price:112.29)
# Ratio 1
# ...
